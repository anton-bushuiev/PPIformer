# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings

import graphein
from torch_geometric.transforms import Compose

from ppiformer.data.dataset import PPIInMemoryDataset
from ppiformer.data.loader import get_dataloader
from ppiformer.data.transforms import *
from ppiformer.data.visualization import plot_data
from ppiformer.definitions import *

# Silence graphein warnings
graphein.verbose(enabled=False)
warnings.filterwarnings("ignore", message=".*The default value of regex will change.*")
# Out:
# [01/24/24 14:39:37] WARNING  To use the Graphein submodule                                         ]8;id=647444;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/features/sequence/embeddings.py\embeddings.py]8;;\:]8;id=711655;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/features/sequence/embeddings.py#44\44]8;;\
#                              graphein.protein.features.sequence.embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via conda
#                              Alternatively, you can install graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:39:38] WARNING  To use the Graphein submodule graphein.protein.visualisation, you  ]8;id=479822;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/visualisation.py\visualisation.py]8;;\:]8;id=321087;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/visualisation.py#35\35]8;;\
#                              need to install: pytorch3d
#                              To do so, use the following command: conda install -c pytorch3d
#                              pytorch3d
#                     WARNING  To use the Graphein submodule graphein.protein.meshes, you need to        ]8;id=870869;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/meshes.py\meshes.py]8;;\:]8;id=616504;file:///Users/anton/miniconda3/envs/ppiformer_u/lib/python3.9/site-packages/graphein/protein/meshes.py#29\29]8;;\
#                              install: pytorch3d
#                              To do so, use the following command: conda install -c pytorch3d pytorch3d

# %%
transform = Compose([
    PDBToPyGPretransform(),
    DDGLabelPretransform()
])
data = transform(PPIFORMER_TEST_DATA_DIR / '1bui_A_C.pdb')
print(data)
plot_data(data)
# Out:
# Data(edge_index=[2, 1468], node_id=[124], virtual_c_beta_vector=[124, 3], sequence_neighbour_vector_n_to_c=[124, 3], sequence_neighbour_vector_c_to_n=[124, 3], num_nodes=124, f=[124, 20], x=[124, 3], y=[124], path=/Users/anton/dev/PPIformer/tests/data/1bui_A_C.pdb, mut_ddg=[0], mut_pos=[0], mut_sub=[0], mut_wt=[0], skempi_pdb=[0], skempi_mut=[0], n_muts=0)

# %%
for i in range(3):
    dataloader = get_dataloader(
        f'skempi2_iclr24_split,{i}',
        pretransform=[PDBToPyGPretransform(), DDGLabelPretransform()],
        transform=[],
        fresh=True,
    )
    dataset = dataloader.dataset
    print(dataset)
# Out:
# [01/24/24 14:40:28] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:28] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:28] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:28] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# Process 52188 preparing data: 100%|██████████| 31/31 [00:04<00:00,  6.25it/s]
# Process 52187 preparing data: 100%|██████████| 31/31 [00:04<00:00,  6.21it/s]
# Process 52189 preparing data: 100%|██████████| 31/31 [00:05<00:00,  5.31it/s]
# Process 52186 preparing data: 100%|██████████| 31/31 [00:07<00:00,  3.88it/s]
# skempi2_iclr24_split,0 loaded: PPIInMemoryDataset(124, n_muts=1917)
# PPIInMemoryDataset(124, n_muts=1917)
# Processing...
# [01/24/24 14:40:39] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:39] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:39] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:39] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:40] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:40:40] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
# [01/24/24 14:40:40] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:40:40] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# Process 52196 preparing data: 100%|██████████| 29/29 [00:07<00:00,  3.64it/s]
# Process 52197 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.56it/s]
# Process 52199 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.44it/s]
# Process 52198 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.30it/s]
# Done!
# [01/24/24 14:40:52] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:52] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:52] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:52] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:40:53] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
# [01/24/24 14:40:53] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
# [01/24/24 14:40:53] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
# [01/24/24 14:40:53] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# Process 52209 preparing data: 100%|██████████| 29/29 [00:07<00:00,  3.64it/s]
# Process 52210 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.55it/s]
# Process 52212 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.44it/s]
# Process 52211 preparing data: 100%|██████████| 29/29 [00:08<00:00,  3.33it/s]
# skempi2_iclr24_split,1 loaded: PPIInMemoryDataset(116, n_muts=1868)
# PPIInMemoryDataset(116, n_muts=1868)
# Processing...
# [01/24/24 14:41:05] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:05] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:05] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:05] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:05] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# Process 52227 preparing data: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]]
# Process 52225 preparing data: 100%|██████████| 22/22 [00:05<00:00,  3.77it/s]
# Process 52226 preparing data: 100%|██████████| 22/22 [00:06<00:00,  3.50it/s]
# Process 52224 preparing data: 100%|██████████| 22/22 [00:07<00:00,  3.00it/s]
# Process 52223 preparing data: 100%|██████████| 22/22 [00:08<00:00,  2.66it/s]
# Done!
# [01/24/24 14:41:17] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:17] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:17] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:17] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:17] WARNING  To use the Graphein submodule      embeddings.py:44
#                              graphein.protein.features.sequence
#                              .embeddings, you need to install:
#                              biovec
#                              biovec cannot be installed via
#                              conda
#                              Alternatively, you can install
#                              graphein with the extras:
#
#                              pip install graphein[extras]
# [01/24/24 14:41:18] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:41:18] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:41:18] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:41:18] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# [01/24/24 14:41:18] WARNING  To use the Graphein submodule   visualisation.py:35
#                              graphein.protein.visualisation,
#                              you need to install: pytorch3d
#                              To do so, use the following
#                              command: conda install -c
#                              pytorch3d pytorch3d
#                     WARNING  To use the Graphein submodule          meshes.py:29
#                              graphein.protein.meshes, you need to
#                              install: pytorch3d
#                              To do so, use the following command:
#                              conda install -c pytorch3d pytorch3d
# Process 52240 preparing data: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]]
# Process 52238 preparing data: 100%|██████████| 22/22 [00:05<00:00,  3.85it/s]
# Process 52239 preparing data: 100%|██████████| 22/22 [00:06<00:00,  3.59it/s]
# Process 52237 preparing data: 100%|██████████| 22/22 [00:07<00:00,  3.06it/s]
# Process 52236 preparing data: 100%|██████████| 22/22 [00:08<00:00,  2.70it/s]
# skempi2_iclr24_split,2 loaded: PPIInMemoryDataset(89, n_muts=1858)
# PPIInMemoryDataset(89, n_muts=1858)
